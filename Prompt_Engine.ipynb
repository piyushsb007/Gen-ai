# %%
# !pip install -U langchain langchain-core langchain-community
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (1.2.15)
# Requirement already satisfied: langchain-core in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (1.2.28)
# Requirement already satisfied: langchain-community in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (0.4.1)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langchain) (1.1.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langchain-core) (0.7.30)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langchain-core) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langchain-community) (1.0.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langchain-community) (2.0.49)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langchain-community) (3.13.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langchain-community) (2.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.1 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.6.3)
# Requirement already satisfied: greenlet>=1 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.4.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in C:\Users\PiyushShaileshBorse\AppData\Roaming\Python\Python312\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000022DBE707500>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/langchain/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000022DC24D6870>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/langchain/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000022DC24F9490>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/langchain/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000022DC24F96A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/langchain/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000022DC24F9880>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/langchain/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000022DC24FB950>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/langchain-core/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000022DC24FBAD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/langchain-core/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000022DC24FBD40>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/langchain-core/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000022DC24FBF20>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/langchain-core/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000022DC24FBE60>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/langchain-core/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000022DC2514800>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/langchain-community/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000022DC24FB590>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/langchain-community/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000022DC24FB710>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/langchain-community/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000022DC24FBE60>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/langchain-community/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000022DC24FB8C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/langchain-community/

# %%
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate

# %% [markdown]
# # Task 1: Replace Hardcoded Prompts

# %%
template = "Explain {topic} in simple terms for beginners" 

prompt_template = PromptTemplate(
    input_variable = ["topic"],
    template = template
)
# Example
print(prompt_template.format(topic="Artificial Intelligence"))
# Out:
# Explain Artificial Intelligence in simple terms for beginners

# %% [markdown]
# # Task 2: Multi-Input Prompt System

# %%
multi_template = "Explain {topic} for {audience} in a {tone} tone"

multi_prompt = PromptTemplate(
    input_variable = ["topic","audience","tone"],
    template = multi_template
)

# Example
print(multi_prompt.format(topic="AI", audience="beginners", tone="friendly"))
print(multi_prompt.format(topic="Python", audience="kids", tone="fun"))
print(multi_prompt.format(topic="Deep Learning", audience="engineers", tone="technical"))
# Out:
# Explain AI for beginners in a friendly tone
# Explain Python for kids in a fun tone
# Explain Neural Networks for engineers in a technical tone

# %% [markdown]
# # Task 3: Prompt Variations Engine

# %%
# PromptTemplates  
# Teaching →
teaching_prompt = PromptTemplate(
    input_variable = ["topic"],
    template = "Explain {topic} clearly step by step"
)

# Interview → 
interview_prompt = PromptTemplate(
    input_variable = ["topic"],
    template = "Ask 3 questions about {topic}"
)

# Storytelling → 
storytelling_prompt = PromptTemplate(
    input_variable = ["topic"],
    template = "Explain {topic} as a story"
)

topic = "Machine Learning"

# Example 

print(teaching_prompt.format(topic=topic))
print(interview_prompt.format(topic=topic))
print(storytelling_prompt.format(topic=topic))
# Out:
# Explain Machine Learning clearly step by step
# Ask 3 questions about Machine Learning
# Explain Machine Learning as a story

# %% [markdown]
# # Task 4: ChatPromptTemplate System

# %%
# from langchain.prompts import ChatPromptTemplate

chat_template = ChatPromptTemplate.from_messages([
    ('system','You are a {role}'),
    ('user','Explain {topic}')
])

prompt = chat_template.format_messages(
    role = 'teacher',
    topic = 'Neural Networks'
)

print(prompt)
# Out:
# [SystemMessage(content='You are a teacher', additional_kwargs={}, response_metadata={}), HumanMessage(content='Explain Neural Networks', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# # Task 5: Input Validation Layer

# %%
def input_validation(audience,tone):
    vaild_audience = ["beginner", "intermediate", "expert"]
    vaild_tone = ["formal", "casual", "fun"] 

    if audience not in vaild_audience:
        print("Invalid audience! Default = beginner")
        audience = "beginner"

    if tone not in vaild_tone:
        print("Invalid tone! Default = casual ")
        tone = "casual"

    return audience,tone

# Test Case:
aud , tone = input_validation("Kids","cool")
print(aud,tone)
# Out:
# Invalid audience! Default = beginner
# Invalid tone! Default = casual
# beginner casual

# %% [markdown]
# # Task 6: Prompt Generator App

# %%
def generate_prompt(topic, audience, tone, style):
    audience , tone = input_validation(audience,tone)

    if style == "teaching":
        template = "Explain {topic} for {audience} in a {tone} teaching style"
    elif style == "interview":
        template = "Ask interview questions about {topic} for {audience} in a {tone} tone"
    elif style == "storytelling":
        template = "Explain {topic} for {audience} in a {tone} storytelling style"
    else:
        raise ValueError("Invalid Style")

    prompt = PromptTemplate(
        input_variable = ["topic","audience","tone"],
        template = template
    )

    return prompt.format(topic=topic,audience=audience,tone=tone)

# Example 
print(generate_prompt("Neural Networks","beginner","fun","storytelling"))
# Out:
# Explain Neural Networks for beginner in a fun storytelling style

# %% [markdown]
# # Task 7: Template Reusability Test

# %%
reusable_template = PromptTemplate(
    input_variables = ["topic","audience","tone"],
    template = "Explain {topic} for {audience} in a {tone}"
)

inputs = [
    ("Block Chain", "beginner", "fun"),
    ("Python", "expert", "formal"),
    ("DBMS", "expert", "casual"),
    ("Cloud Computing", "beginner", "formal"),
    ("NLP", "intermediate", "fun")
]

for topic,audience,tone in inputs:
    print(reusable_template.format(topic=topic,audience=audience,tone=tone))
# Out:
# Explain Block Chain for beginner in a fun
# Explain Python for expert in a formal
# Explain DBMS for expert in a casual
# Explain Cloud Computing for beginner in a formal
# Explain NLP for intermediate in a fun

# %% [markdown]
# # This System follows a Pipeline:
# # User Input → Validation → Prompt Template → Dynamic Prompt Generation → Output
